# %% [markdown]
# # Heisenberg FSS — O(3) Universality Validation
#
# Finite-size scaling analysis of the classical Heisenberg model on cubic lattices.
# Target: recover O(3) exponents ν=0.7112, γ=1.3960, β=0.3646 and Tc=1.4432 J/kB.
#
# ## Sections
# 1. Load `heisenberg_fss_N*.csv` — plot E, |M|, Cv, χ vs T with error bars
# 2. Binder cumulant U(T) crossings → Tc with uncertainty
# 3. Peak scaling: χ_max ~ L^{γ/ν}, M(Tc) ~ L^{-β/ν}
# 4. Scaling collapse → ν
# 5. Summary table: measured vs O(3) theory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path('data')
SIZES = [8, 12, 16, 20, 24, 32]

dfs = {}
for n in SIZES:
    path = DATA_DIR / f'heisenberg_fss_N{n}.csv'
    if path.exists():
        dfs[n] = pd.read_csv(path)
    else:
        print(f'Missing: {path}')

print(f'Loaded {len(dfs)} size(s):', list(dfs.keys()))
if dfs:
    display(next(iter(dfs.values())).head())

# %% [markdown]
# ## 1. Raw observables
#
# TODO: Plot E, |M|, Cv, χ vs T for each size with error bars.

# %% [markdown]
# ## 2. Binder cumulant crossings → Tc
#
# U = 1 − ⟨m⁴⟩ / (3⟨m²⟩²)
#
# TODO: Compute U(T) per size, find pairwise crossings, report Tc ± uncertainty.

# %% [markdown]
# ## 3. Peak scaling
#
# TODO: χ_max(L) ~ L^{γ/ν}, M(Tc, L) ~ L^{-β/ν}

# %% [markdown]
# ## 4. Scaling collapse
#
# TODO: Collapse M·L^{β/ν} vs (T−Tc)·L^{1/ν}

# %% [markdown]
# ## 5. Summary table
#
# | Quantity | Measured | O(3) theory |
# |----------|----------|-------------|
# | Tc       | —        | 1.4432 J/kB |
# | ν        | —        | 0.7112      |
# | γ        | —        | 1.3960      |
# | β        | —        | 0.3646      |
